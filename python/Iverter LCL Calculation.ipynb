# %%
from math import pi , floor

# %%
Vn=220
In=15
Fs=10E3
E=540
F=50
Wn=2*pi*F
Ws=2*pi*Fs
Wf=Ws/8
P3=3*Vn*In

print('Wn =', floor(100*Wn)/100, 'rad/s')
print('Ws =', floor(100*Ws)/100, 'rad/s')
print('Wf =', floor(100*Wf)/100, 'rad/s')
print('Output Power=',floor(P3)/1000,'Kw')
# Out:
# Wn = 314.15 rad/s
# Ws = 62831.85 rad/s
# Wf = 7853.98 rad/s
# Output Power= 9.9 Kw

# %%
L1=10*E/(8*3*In*Fs)
print('L1 >',floor(100*L1*1E3)/100, 'mH')
# Out:
# L1 > 1.5 mH

# %%
Cmax=In/(20*Wn*Vn)
print('Cmax=',floor(10*Cmax*1E6)/10, 'uF')
# Out:
# Cmax= 10.8 uF

# %%
Lmax=Vn/(10*Wn*In)
print('Lmax=', floor(100*Lmax*1E3)/100, 'mH')
# Out:
# Lmax= 4.66 mH

# %%
C=10E-6
L1=4.6E-3

# %%
AA=Wf*Wf*L1*C-1
print(AA)
L2=L1/(AA-1)
print('L2=', L2*1E3, 'mH')
# Out:
# 1.8375112653131906
# L2= 5.492463433646844 mH

# %%
L2=5.4E-3
L=L1+L2

# %%
print('L1=', L1*1E3, 'mH')
print('L2=', L2*1E3, 'mH')
print('L =', L*1E3, 'mH')
print('C =', C *1E6, 'uF')
# Out:
# L1= 4.6 mH
# L2= 5.4 mH
# L = 10.0 mH
# C = 10.0 uF

# %%
Wf=math.sqrt((L1+L2)/(L1*L2*C))
print('Wf=',floor(100*Wf)/100, 'rad/s')
# Out:
# Wf= 6344.89 rad/s

# %%
print('Ws/Wf=', floor(100*Ws/Wf)/100)
# Out:
# Ws/Wf= 9.9
