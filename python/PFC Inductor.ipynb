# %%
import math

# %%
Vacmin=200
Vacmax=240
Eff=0.93
Po=4800
Vo=400
Iripple=0.35
Fs=60E3

# %%
ILavgmax = math.sqrt(2) * Po / Vacmin
print("ILavgmax=",ILavgmax, "A")
# Out:
# ILavgmax= 33.941125496954285 A

# %%
L = (Eff * Vacmin * Vacmin) * (1 - math.sqrt(2) * Vacmin / Vo)/(Iripple * Fs * Po)
print("L=",L*1e6, "uH")
# Out:
# L= 108.09154503829792 uH
