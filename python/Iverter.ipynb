# %%
import math

# %%
Vn=220
In=15
Fs=10E3
E=680
F=50
Wn=2*math.pi*F
Ws=2*math.pi*Fs
Wf=Ws/8
print('Wn =', Wn, 'rad/s')
print('Ws =', Ws, 'rad/s')
print('Wf =', Wf, 'rad/s')
# Out:
# Wn = 314.1592653589793 rad/s
# Ws = 62831.853071795864 rad/s
# Wf = 7853.981633974483 rad/s

# %%
L1=10*E/(8*3*In*Fs)
print('L1 >',L*1E3, 'mH')
# Out:
# L1 > 6.3999999999999995 mH

# %%
Cmax=In/(20*W*Vn)
print('Cmax=',Cmax*1E6, 'uF')
# Out:
# Cmax= 10.851473392629226 uF

# %%
Lmax=Vn/(10*W*In)
print('Lmax=', Lmax*1E3, 'mH')
# Out:
# Lmax= 4.668544997362264 mH

# %%
C=10E-6
L1=3.3E-3

# %%
L2=L1/(Wf*Wf*L1*C-1)
print('L2=', L2*1E3, 'mH')
# Out:
# L2= 3.186540338737926 mH

# %%
L2=3.1E-3
L=L1+L2

# %%
print('L1=', L1*1E3, 'mH')
print('L2=', L2*1E3, 'mH')
print('L =', L*1E3, 'mH')
print('C =', C *1E6, 'uF')
# Out:
# L1= 3.3 mH
# L2= 3.1 mH
# L = 6.3999999999999995 mH
# C = 10.0 uF

# %%
Wf=math.sqrt((L1+L2)/(L1*L2*C))
print('Wf=',Wf, 'rad/s')
# Out:
# Wf= 7909.55718224221 rad/s

# %%
print('Ws/Wf=', Ws/Wf)
# Out:
# Ws/Wf= 7.9437889661964896
